# %%
#CCLE_cell_lines.corr()
#sns.heatmap(CCLE_cell_lines.corr(), cmap = "coolwarm")
"""corr_matrix = CCLE_cell_lines.corr().abs()
high_corr_var=np.where(corr_matrix>0.6)
high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
#high_corr_var[:50]"""
"""import umap.plot
from bokeh.plotting import output_notebook
output_notebook()

kmeans_labels_c = KMeans(n_clusters=37, random_state=0).fit_predict(CCLE_cell_lines.T)
indices_one = kmeans_labels_c == 36
indices_zero = kmeans_labels_c == 11
kmeans_labels_c[indices_one] = 11 # replacing 1s with 0s
kmeans_labels_c[indices_zero] = 36
kmeans_labels_c[1] = 37; kmeans_labels_c[2] = 38; kmeans_labels_c[3] = 39

hover_data = pd.DataFrame({'index':np.arange(938),
                           'label':kmeans_labels_c})

mapper = umap.UMAP().fit(CCLE_cell_lines.T)
p = umap.plot.interactive(mapper, labels=kmeans_labels_c, hover_data = hover_data, point_size=7.5)
umap.plot.show(p)"""


"""kmeans_labels_c = KMeans(n_clusters=36, random_state=0).fit_predict(CCLE_cell_lines.T)
indices_one = kmeans_labels_c == 36
indices_zero = kmeans_labels_c == 11
kmeans_labels_c[indices_one] = 11 # replacing 1s with 0s
kmeans_labels_c[indices_zero] = 36
kmeans_labels_c[1] = 36; kmeans_labels_c[2] = 36; kmeans_labels_c[3] = 36

standard_embedding = umap.UMAP(random_state=42).fit_transform(CCLE_cell_lines.T)
fig, ax = plt.subplots(figsize=(35,35))
plt.scatter(standard_embedding[:, 0].reshape(938,1), standard_embedding[:, 1].reshape(938,1), c=kmeans_labels_c, s=25.0, cmap='Spectral')
for i in range(938):
    plt.annotate(kmeans_labels_c[i], (list(standard_embedding[:, 0])[i] + 0.05, list(standard_embedding[:, 1])[i] + 0.05))
    
cbar = plt.colorbar(boundaries=np.arange(36)-0.5)
cbar.set_ticks(np.arange(35))
cbar.set_ticklabels(list(set(kmeans_labels_c)))"""
# Out:
# "kmeans_labels_c = KMeans(n_clusters=36, random_state=0).fit_predict(CCLE_cell_lines.T)\nindices_one = kmeans_labels_c == 36\nindices_zero = kmeans_labels_c == 11\nkmeans_labels_c[indices_one] = 11 # replacing 1s with 0s\nkmeans_labels_c[indices_zero] = 36\nkmeans_labels_c[1] = 36; kmeans_labels_c[2] = 36; kmeans_labels_c[3] = 36\n\nstandard_embedding = umap.UMAP(random_state=42).fit_transform(CCLE_cell_lines.T)\nfig, ax = plt.subplots(figsize=(35,35))\nplt.scatter(standard_embedding[:, 0].reshape(938,1), standard_embedding[:, 1].reshape(938,1), c=kmeans_labels_c, s=25.0, cmap='Spectral')\nfor i in range(938):\n    plt.annotate(kmeans_labels_c[i], (list(standard_embedding[:, 0])[i] + 0.05, list(standard_embedding[:, 1])[i] + 0.05))\n    \ncbar = plt.colorbar(boundaries=np.arange(36)-0.5)\ncbar.set_ticks(np.arange(35))\ncbar.set_ticklabels(list(set(kmeans_labels_c)))"

# %%
#PanRef_cell_line.corr()
"""corr_matrix_2 = PanRef_cell_line.corr().abs()
high_corr_var=np.where(corr_matrix_2>0.4)
high_corr_var=[(corr_matrix_2.columns[x],corr_matrix_2.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
#high_corr_var[:50]"""
#sns.heatmap(PanRef_cell_line.corr(), cmap = "coolwarm")
"""import umap.plot
from bokeh.plotting import output_notebook
output_notebook()

kmeans_labels = KMeans(n_clusters=34, random_state=0).fit_predict(PanRef_cell_line.T)
indices_one = kmeans_labels == 33
indices_zero = kmeans_labels == 0
kmeans_labels[indices_one] = 0 
kmeans_labels[indices_zero] = 33
kmeans_labels[0] = 34; kmeans_labels[1] = 35; kmeans_labels[2] = 36; kmeans_labels[3] = 37

hover_data = pd.DataFrame({'index':np.arange(11073),
                           'label':kmeans_labels})

mapper = umap.UMAP().fit(PanRef_cell_line.T)
p = umap.plot.interactive(mapper, labels=kmeans_labels, hover_data = hover_data, point_size=7.5)
umap.plot.show(p)"""

"""from sklearn.manifold import TSNE
tsne = TSNE(n_components=2).fit_transform(PanRef_T)
plt.scatter(tsne[:,0], tsne[:,1],c=kmeans_labels,cmap='Spectral')"""
# Out:
# "from sklearn.manifold import TSNE\ntsne = TSNE(n_components=2).fit_transform(PanRef_T)\nplt.scatter(tsne[:,0], tsne[:,1],c=kmeans_labels,cmap='Spectral')"

# %%
PanRef = pd.read_table('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/Ref/EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv')
PanRef.head()
# Out:
#        gene_id  TCGA-OR-A5J1-01A-11R-A29S-07  TCGA-OR-A5J2-01A-11R-A29S-07  \
# 0  ?|100130426                        0.0000                        0.0000
# 1  ?|100133144                        3.2661                        2.6815
# 2  ?|100134869                        3.9385                        8.9948
# 3      ?|10357                      149.1350                       81.0777
# 4      ?|10431                     2034.1000                     1304.9300
#
#    TCGA-OR-A5J3-01A-11R-A29S-07  TCGA-OR-A5J5-01A-11R-A29S-07  \
# 0                        0.0000                        0.0000
# 1                        1.7301                        0.0000
# 2                        6.5650                        1.5492
# 3                       86.4879                       53.9117
# 4                     1054.6600                     2350.8900
#
#    TCGA-OR-A5J6-01A-31R-A29S-07  TCGA-OR-A5J7-01A-11R-A29S-07  \
# 0                        0.0000                        0.0000
# ...

# %%
PanRef.sum()
# Out:
# gene_id                         ?|100130426?|100133144?|100134869?|10357?|1043...
# TCGA-OR-A5J1-01A-11R-A29S-07                                          1.75631e+07
# TCGA-OR-A5J2-01A-11R-A29S-07                                          1.90867e+07
# TCGA-OR-A5J3-01A-11R-A29S-07                                           2.1641e+07
# TCGA-OR-A5J5-01A-11R-A29S-07                                          2.06909e+07
#                                                       ...
# TCGA-CG-4472-01A-01R-1157-13                                          1.84405e+07
# TCGA-CG-4474-01A-02R-1157-13                                          1.79555e+07
# TCGA-CG-4475-01A-01R-1157-13                                          1.96248e+07
# TCGA-CG-4476-01A-01R-1157-13                                          1.79111e+07
# TCGA-CG-4477-01A-01R-1157-13                                          1.82207e+07
# Length: 11070, dtype: object

# %%
CCLE = pd.read_table('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/Ref/trimmed_counts.tsv')
CCLE.head()
# Out:
#                                           Unnamed: 0  G20460.COR-L24.2  \
# 0  ENST00000000233.9|ENSG00000004059.10|OTTHUMG00...          5009.960
# 1  ENST00000000412.7|ENSG00000003056.7|OTTHUMG000...          5968.900
# 2  ENST00000000442.10|ENSG00000173153.13|OTTHUMG0...           685.996
# 3  ENST00000001008.5|ENSG00000004478.7|OTTHUMG000...         12024.300
# 4  ENST00000001146.6|ENSG00000003137.8|OTTHUMG000...           883.371
#
#    G20461.HSC-3.2  G20462.KMS-11.2  G20463.C2BBe1.2  G20464.COR-L311.2  \
# 0        4064.570       3825.25000        7337.5200            5467.37
# 1       13559.800       8107.46000       20366.2000            2490.47
# 2        1475.830        505.59400        1142.0700            2096.96
# 3       12121.000      16433.40000       20139.3000           11343.20
# 4         151.815          6.05758          32.0271               0.00
#
#    G20465.HCC-33.2  G20466.5637.2  G20467.COR-L279.2  G20468.DMS_53.2  ...  \
# ...

# %%
CCLE.sum()
# Out:
# Unnamed: 0            ENST00000000233.9|ENSG00000004059.10|OTTHUMG00...
# G20460.COR-L24.2                                            6.45686e+07
# G20461.HSC-3.2                                              6.39617e+07
# G20462.KMS-11.2                                             4.98358e+07
# G20463.C2BBe1.2                                             7.09623e+07
#                                             ...
# G41752.HT115.1                                              1.41408e+08
# G41753.HT55.1                                               6.64386e+07
# G41807.HOP-62.1                                             7.04909e+07
# G41811.EKVX.1                                               6.95505e+07
# G41821.COLO-680N.1                                          8.17941e+07
# Length: 935, dtype: object

# %%
cell_line.sum()
# Out:
# c1_1    4766889
# c2_1    4636266
# c3_1    4762387
# c4_1    4761990
# dtype: int64

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import plotly.io as plt_io
import plotly.graph_objects as go
from matplotlib import pyplot as plt
import umap; import umap.plot
import sklearn.cluster as cluster
import seaborn as sns; sns.set()
import gseapy as gp
from pyensembl import EnsemblRelease as ER
from sklearn.feature_selection import VarianceThreshold
from sklearn.cluster import KMeans
from scipy.spatial.distance import cosine
import mygene; mg = mygene.MyGeneInfo()
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler; std_scaler = StandardScaler()

# %% [markdown]
# # Handling the DataFrame

# %%
PanRef = pd.read_table('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/Ref/EBPlusPlusAdjustPANCAN_IlluminaHiSeq_RNASeqV2.geneExp.tsv')
PanRef = PanRef.fillna(0)
PanRef_T = PanRef.T
new_header = PanRef_T.iloc[0] #grab the first row for the header
PanRef_T = PanRef_T[1:] #take the data less the header row
PanRef_T.columns = new_header #set the header row as the df header
PanRef_T.columns = PanRef_T.columns.str.split('|').str[0]
PanRef_T_scaled = StandardScaler().fit_transform(PanRef_T.iloc[:,:])


CCLE = pd.read_table('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/Ref/trimmed_counts.tsv')
CCLE["Unnamed: 0"] = CCLE["Unnamed: 0"].str.split('|').str[1]
CCLE = CCLE.set_index('Unnamed: 0')

c1 = pd.read_csv('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/counts/TE671_S1_L001_exp.txt', sep = "\t", header = None)
c1.columns = ['gene', 'c1_1']
c2 = pd.read_csv('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/counts/TE671_S1_L002_exp.txt', sep = "\t", header = None)
c2.drop(c2.columns[0], axis=1, inplace=True)
c2.columns = ['c2_1']
c3 = pd.read_csv('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/counts/TE671_S1_L003_exp.txt', sep = "\t", header = None)
c3.drop(c3.columns[0], axis=1, inplace=True)
c3.columns = ['c3_1']
c4 = pd.read_csv('D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/counts/TE671_S1_L004_exp.txt', sep = "\t", header = None)
c4.drop(c4.columns[0], axis=1, inplace=True)
c4.columns = ['c4_1']

cell_line = pd.concat([c1, c2, c3, c4], axis=1)
cell_line = cell_line[cell_line['gene'].str.contains('ENSG')]
l = list(cell_line["gene"].str[:15])
cell_line = cell_line.set_index('gene')
cell_line.head()
# Out:
#                     c1_1  c2_1  c3_1  c4_1
# gene
# ENSG00000000003.13     2     1     2     2
# ENSG00000000005.5      4     2     2     3
# ENSG00000000419.11     7    10    19    24
# ENSG00000000457.12   733   647   662   702
# ENSG00000000460.15   588   547   586   533

# %%
threshold = 5.0
selector = VarianceThreshold(threshold)
variable_genes = selector.fit(cell_line.T)
idx = np.where(variable_genes.variances_ > threshold)[0]
cell_line = cell_line.iloc[idx, :]
cell_line.head()
# Out:
#                     c1_1  c2_1  c3_1  c4_1
# gene
# ENSG00000000419.11     7    10    19    24
# ENSG00000000457.12   733   647   662   702
# ENSG00000000460.15   588   547   586   533
# ENSG00000001036.12    19    16    15    22
# ENSG00000001167.13    23    19    13    17

# %%
cell_line_normalised = pd.DataFrame(std_scaler.fit_transform(cell_line.iloc[:,:]), columns=cell_line.iloc[:,:].columns)
cell_line_normalised["gene"] = cell_line.index; 
cell_line_normalised = cell_line_normalised.set_index('gene')
print(cell_line_normalised.shape)
cell_line_normalised.head()
# Out:
# (12731, 4)
#                         c1_1      c2_1      c3_1      c4_1
# gene
# ENSG00000000419.11 -0.096452 -0.095725 -0.093303 -0.092121
# ENSG00000000457.12  0.096972  0.079073  0.078267  0.089113
# ENSG00000000460.15  0.058341  0.051632  0.057988  0.043938
# ENSG00000001036.12 -0.093255 -0.094078 -0.094370 -0.092656
# ENSG00000001167.13 -0.092189 -0.093255 -0.094904 -0.093992

# %%
intersection = set(list(cell_line_normalised.index)).intersection(set(list(CCLE.index)))
cell_line_normalised = cell_line_normalised[pd.DataFrame(cell_line_normalised.index.tolist()).isin(intersection).any(1).values]
CCLE = CCLE[pd.DataFrame(CCLE.index.tolist()).isin(cell_line_normalised.index).any(1).values]
CCLE_normalised = pd.DataFrame(std_scaler.fit_transform(CCLE.iloc[:,:]), columns=CCLE.iloc[:,:].columns)
CCLE_normalised.index = CCLE.index
CCLE_normalised.index = CCLE_normalised.index.str[:15]
cell_line_normalised.index = cell_line_normalised.index.str[:15]
print(CCLE_normalised.shape)
CCLE_normalised.head()
# Out:
# (7436, 934)
#                  G20460.COR-L24.2  G20461.HSC-3.2  G20462.KMS-11.2  \
# Unnamed: 0
# ENSG00000004478          0.974358        0.640379         1.231873
# ENSG00000007520         -0.009116        0.024674         0.082091
# ENSG00000008438         -0.061734       -0.050784        -0.049563
# ENSG00000010017          0.466188        0.127052         0.300550
# ENSG00000023516          0.210903        0.300952         0.102945
#
#                  G20463.C2BBe1.2  G20464.COR-L311.2  G20465.HCC-33.2  \
# Unnamed: 0
# ENSG00000004478         1.134850           0.389413         2.209593
# ENSG00000007520         0.053886          -0.005141         0.013380
# ENSG00000008438        -0.053850          -0.041387        -0.059370
# ENSG00000010017         0.145686           0.169136         0.434888
# ENSG00000023516         0.476096           0.249638         0.440259
#
#                  G20466.5637.2  G20467.COR-L279.2  G20468.DMS_53.2  \
# Unnamed: 0
# ...

# %%
k = pd.read_csv('getgenes.csv')
intersection_2 = set(list(PanRef_T.columns)).intersection(set(list(k["symbol"])))
PanRef_T = PanRef_T[intersection_2]
# Out:
# C:\Users\Onkar\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (106,107,110,111,120,121,122,123,159,167,168,172,174,178,179,180,181,182,186,187,188,197,200,201,202,203,204,205,206,207,208,209,210,211,212,218,219,224,225,226,227,228,229,230,231,232,236,237,239,240,241,242,243,244) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# # CCLE and 4 replicates

# %%
cell_line_T = cell_line_normalised.T
CCLE_normalised = CCLE_normalised[~CCLE_normalised.index.duplicated(keep='first')]
CCLE_cell_lines = pd.concat([cell_line_T.T, CCLE_normalised], axis=1)

# %%
kmeans_labels_c = KMeans(n_clusters=36, random_state=0).fit_predict(CCLE_cell_lines.T)
indices_one = kmeans_labels_c == 35
indices_zero = kmeans_labels_c == 11
kmeans_labels_c[indices_one] = 11 # replacing 1s with 0s
kmeans_labels_c[indices_zero] = 35
#kmeans_labels_c[1] = 36; kmeans_labels_c[2] = 36; kmeans_labels_c[3] = 36

standard_embedding = umap.UMAP(random_state=42).fit_transform(CCLE_cell_lines.T)
fig, ax = plt.subplots(figsize=(15,15))
plt.scatter(standard_embedding[:, 0].reshape(938,1), standard_embedding[:, 1].reshape(938,1), c=kmeans_labels_c, s=30.0, cmap='Spectral')

kmeans_labels_cancer_match = "Soft-tissue-Cancer"
kmeans_labels_cell_line = "TE671-Cells"
for i in range(1):
    plt.annotate(kmeans_labels_cell_line, (list(standard_embedding[:1, 0])[i] + 0.05, list(standard_embedding[:1, 1])[i] + 0.05))
for i in range(1):
    plt.annotate(kmeans_labels_cancer_match, (list(standard_embedding[128:129, 0])[i] + 0.01, list(standard_embedding[128:129, 1])[i] + 0.01))
    
cbar = plt.colorbar(boundaries=np.arange(36)-0.5)
cbar.set_ticks(np.arange(35))
cbar.set_ticklabels(list(set(kmeans_labels_c)))

# %% [markdown]
# # TCGA and 4 replicates

# %%
PanRef_T_normalised = pd.DataFrame(std_scaler.fit_transform(PanRef_T.T.iloc[:,:]), columns=PanRef_T.T.iloc[:,:].columns)
PanRef_T_normalised["gene_id"] = PanRef_T.T.index; PanRef_T_normalised = PanRef_T_normalised.set_index("gene_id")
PanRef_T_normalised = PanRef_T_normalised.sort_index()

cell_line_normalised = cell_line_T.T.reset_index()
cell_line_normalised["gene_id"] = k["symbol"]
cell_line_normalised = cell_line_normalised.dropna()
cell_line_normalised = cell_line_normalised.drop(["gene"], axis=1)
cell_line_normalised = cell_line_normalised.set_index("gene_id")
cell_line_normalised = cell_line_normalised.T[intersection_2].T
cell_line_normalised = cell_line_normalised.sort_index()

PanRef_cell_line = pd.concat([cell_line_normalised, PanRef_T_normalised], axis=1)
PanRef_cell_line.head()
# Out:
#              c1_1      c2_1      c3_1      c4_1  TCGA-OR-A5J1-01A-11R-A29S-07  \
# gene_id
# A4GNT   -0.094854 -0.095999 -0.097306 -0.095863                     -0.340024
# ABCD1   -0.093255 -0.093529 -0.091969 -0.093190                      0.540612
# ABT1    -0.093788 -0.095450 -0.094904 -0.095329                     -0.061114
# ABTB2   -0.071408 -0.069930 -0.069022 -0.065925                     -0.301608
# ACAT2    0.917296  0.956904  0.941723  0.943158                      1.324220
#
#          TCGA-OR-A5J2-01A-11R-A29S-07  TCGA-OR-A5J3-01A-11R-A29S-07  \
# gene_id
# A4GNT                       -0.414667                     -0.120348
# ABCD1                        0.469854                      0.041778
# ABT1                        -0.106366                     -0.067985
# ABTB2                       -0.399908                     -0.078647
# ACAT2                       -0.157009                      0.303755
#
# ...

# %%
kmeans_labels = KMeans(n_clusters=34, random_state=0).fit_predict(PanRef_cell_line.T)
indices_one = kmeans_labels == 33
indices_zero = kmeans_labels == 0
kmeans_labels[indices_one] = 0 
kmeans_labels[indices_zero] = 33
kmeans_labels[0] = 34; kmeans_labels[1] = 34; kmeans_labels[2] = 34; kmeans_labels[3] = 34
standard_embedding = umap.UMAP(random_state=42).fit_transform(PanRef_cell_line.T)
fig, ax = plt.subplots(figsize=(18,18))
plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=kmeans_labels, s=5.0, cmap='Spectral')

for i in range(1):
    plt.annotate(kmeans_labels[0:1][i], (list(standard_embedding[:1, 0])[i] + 0.05, list(standard_embedding[:1, 1])[i] + 0.05))
for i in range(1):
    plt.annotate(kmeans_labels[4383:4384][i], (list(standard_embedding[4383:4384, 0])[i] + 0.01, list(standard_embedding[4383:4384, 1])[i] + 0.01))
for i in range(1):
    plt.annotate(kmeans_labels[142:143][i], (list(standard_embedding[142:143, 0])[i] + 0.01, list(standard_embedding[142:143, 1])[i] + 0.01))
    
    
cbar = plt.colorbar(boundaries=np.arange(34)-0.5)
cbar.set_ticks(np.arange(34))
cbar.set_ticklabels(list(set(kmeans_labels)))

# %% [markdown]
# # Correlation - Matrices

# %%
#PanRef_cell_line_label.to_csv("PanRef_cell_line_label.csv")
#PanRef_cell_line_label = pd.read_csv("PanRef_cell_line_label.csv")

# %%
PanRef_cell_line_label = PanRef_cell_line.T
PanRef_cell_line_label.reset_index(level=0, inplace=True)
PanRef_cell_line_label = PanRef_cell_line_label.set_index("index")
cs_1 = cosine_similarity(PanRef_cell_line_label)
cs_1 = pd.DataFrame(data = cs_1, columns=PanRef_cell_line_label.index)

cs_1 = cs_1.set_index(PanRef_cell_line_label.index)
PS = PanRef_cell_line_label.T.corr(method="spearman")
PP = PanRef_cell_line_label.T.corr()

# %%
cs_1.sort_values(by="c1_1", ascending = False).head(15)
# Out:
# index                             c1_1      c2_1      c3_1      c4_1  \
# index
# c1_1                          1.000000  0.999396  0.999359  0.999458
# c4_1                          0.999458  0.999467  0.999433  1.000000
# c2_1                          0.999396  1.000000  0.999392  0.999467
# c3_1                          0.999359  0.999392  1.000000  0.999433
# TCGA-C4-A0EZ-01A-21R-A24X-07  0.020182  0.019832  0.022960  0.020019
# TCGA-EY-A547-01A-11R-A27V-07  0.017862  0.017120  0.018507  0.018321
# TCGA-DD-A73G-01A-22R-A32O-07  0.016406  0.016172  0.017018  0.016900
# TCGA-A2-A3XZ-01A-42R-A239-07  0.012841  0.012779  0.012437  0.011997
# TCGA-SR-A6MX-05A-11R-A35L-07  0.012080  0.011439  0.012522  0.012549
# TCGA-DD-A3A5-01A-11R-A22L-07  0.011925  0.013113  0.013848  0.013056
# TCGA-DU-7304-02A-12R-A36H-07  0.011404  0.012533  0.012194  0.012008
# TCGA-EP-A3RK-11A-11R-A22L-07  0.010597  0.011525  0.011464  0.011262
# ...

# %%
PS.sort_values(by="c1_1", ascending = False).head(15)
# Out:
# index                             c1_1      c2_1      c3_1      c4_1  \
# index
# c1_1                          1.000000  0.962466  0.963602  0.960622
# c3_1                          0.963602  0.963276  1.000000  0.963444
# c2_1                          0.962466  1.000000  0.963276  0.957160
# c4_1                          0.960622  0.957160  0.963444  1.000000
# TCGA-AB-3011-03A-01T-0736-13  0.041251  0.036182  0.031572  0.025275
# TCGA-DU-7304-02A-12R-A36H-07  0.040750  0.034807  0.040991  0.040300
# TCGA-WB-A81A-01A-11R-A35L-07  0.040514  0.034628  0.038915  0.037938
# TCGA-V4-A9E9-01A-11R-A405-07  0.039049  0.036458  0.037330  0.034611
# TCGA-AB-2913-03A-01T-0734-13  0.038649  0.036195  0.029975  0.020723
# TCGA-AB-2955-03A-01T-0734-13  0.034852  0.035822  0.031010  0.025277
# TCGA-FG-A6IZ-01A-11R-A31N-07  0.034486  0.030274  0.036969  0.033701
# TCGA-XU-AAXZ-01A-11R-A466-07  0.034414  0.038652  0.042841  0.033010
# ...

# %%
PP.sort_values(by="c1_1", ascending = False).head(15)
# Out:
# index                             c1_1      c2_1      c3_1      c4_1  \
# index
# c1_1                          1.000000  0.999250  0.999210  0.999326
# c4_1                          0.999326  0.999330  0.999289  1.000000
# c2_1                          0.999250  1.000000  0.999238  0.999330
# c3_1                          0.999210  0.999238  1.000000  0.999289
# TCGA-C4-A0EZ-01A-21R-A24X-07  0.022664  0.022224  0.025718  0.022439
# TCGA-EY-A547-01A-11R-A27V-07  0.020058  0.019185  0.020730  0.020536
# TCGA-DD-A73G-01A-22R-A32O-07  0.018424  0.018123  0.019063  0.018943
# TCGA-A2-A3XZ-01A-42R-A239-07  0.014420  0.014321  0.013931  0.013448
# TCGA-SR-A6MX-05A-11R-A35L-07  0.013566  0.012818  0.014026  0.014067
# TCGA-DD-A3A5-01A-11R-A22L-07  0.013391  0.014695  0.015512  0.014634
# TCGA-DU-7304-02A-12R-A36H-07  0.012806  0.014045  0.013659  0.013460
# TCGA-EP-A3RK-11A-11R-A22L-07  0.011900  0.012915  0.012841  0.012624
# ...

# %%
#CCLE_cell_lines_label.to_csv("CCLE_cell_lines_label.csv")
#CCLE_cell_lines_label = pd.read_csv("CCLE_cell_lines_label.csv")

# %%
CCLE_cell_lines_label = CCLE_cell_lines.T
CCLE_cell_lines_label.reset_index(level=0, inplace=True)
CCLE_cell_lines_label = CCLE_cell_lines_label.set_index("index")
cs_1 = cosine_similarity(CCLE_cell_lines_label)
cs_1 = pd.DataFrame(data = cs_1, columns=CCLE_cell_lines_label.index)

cs_1 = cs_1.set_index(CCLE_cell_lines_label.index)
CS = CCLE_cell_lines_label.T.corr(method="spearman")
CP = CCLE_cell_lines_label.T.corr()

# %%
cs_1.sort_values(by="c1_1", ascending = False).head(15)
# Out:
# index                     c1_1      c2_1      c3_1      c4_1  \
# index
# c1_1                  1.000000  0.999983  0.999982  0.999977
# c2_1                  0.999983  1.000000  0.999985  0.999985
# c3_1                  0.999982  0.999985  1.000000  0.999981
# c4_1                  0.999977  0.999985  0.999981  1.000000
# G28561.NCI-H1693.1    0.722802  0.721969  0.722675  0.721158
# G27452.SK-LU-1.2      0.655143  0.654361  0.654874  0.653602
# G30621.TGBC11TKB.1    0.640397  0.639611  0.640140  0.638887
# G26185.HCC70.2        0.636704  0.635900  0.636574  0.635239
# G27347.BV-173.1       0.590930  0.590217  0.590747  0.589550
# G28037.KYO-1.1        0.568094  0.567375  0.567934  0.566774
# G26203.NCI-H838.2     0.548738  0.548029  0.548505  0.547427
# G28573.OV56.1         0.533678  0.532964  0.533522  0.532432
# G27317.HCC1806.1      0.525444  0.524739  0.525300  0.524237
# G28559.NCI-H2172.1    0.517909  0.517238  0.517791  0.516715
# ...

# %%
CS.sort_values(by="c1_1", ascending = False).head(15)
# Out:
# index                    c1_1      c2_1      c3_1      c4_1  G20460.COR-L24.2  \
# index
# c1_1                 1.000000  0.968190  0.968394  0.966013          0.132823
# c3_1                 0.968394  0.967539  1.000000  0.967990          0.134272
# c2_1                 0.968190  1.000000  0.967539  0.967457          0.131538
# c4_1                 0.966013  0.967457  0.967990  1.000000          0.132493
# G28597.NCI-H1869.1   0.179724  0.178890  0.179428  0.177890          0.718254
# G28023.KMRC-1.1      0.175231  0.173342  0.170667  0.170959          0.712916
# G26240.MIA_PaCa-2.2  0.170965  0.169654  0.169667  0.167732          0.754945
# G30624.UACC-812.1    0.170082  0.165833  0.169544  0.165894          0.719632
# G27542.SF539.2       0.166863  0.168945  0.168113  0.167604          0.801030
# G28879.Hs_840.T.3    0.164414  0.166047  0.165511  0.164637          0.774654
# G27356.COLO-800.1    0.163971  0.163365  0.166359  0.162504          0.781276
# ...

# %%
CP = CP.sort_values(by="c1_1", ascending = False).head(15)
CP = CP.iloc[4:10,:4]
CP.to_csv("CP.csv")

# %%
CP
# Out:
# index                   c1_1      c2_1      c3_1      c4_1
# index
# G28561.NCI-H1693.1  0.722787  0.721954  0.722660  0.721143
# G27452.SK-LU-1.2    0.655110  0.654328  0.654842  0.653569
# G30621.TGBC11TKB.1  0.640332  0.639546  0.640075  0.638822
# G26185.HCC70.2      0.636645  0.635841  0.636515  0.635181
# G27347.BV-173.1     0.590802  0.590089  0.590619  0.589422
# G28037.KYO-1.1      0.568015  0.567295  0.567855  0.566694

# %% [markdown]
# # Correlation between CCLE and TCGA

# %%
"""CCLE_normalised_TCGA = CCLE_normalised
CCLE_normalised_TCGA = CCLE_normalised_TCGA.reset_index()
CCLE_normalised_TCGA["gene_id"] = k["symbol"]
CCLE_normalised_TCGA = CCLE_normalised_TCGA.dropna()
CCLE_normalised_TCGA = CCLE_normalised_TCGA.drop(["Unnamed: 0"], axis=1)
CCLE_normalised_TCGA = CCLE_normalised_TCGA.set_index("gene_id")
CCLE_normalised_TCGA = CCLE_normalised_TCGA.T[cell_line_normalised.index]


CCLE_TCGA = pd.concat([PanRef_T_normalised,CCLE_normalised_TCGA.T],axis=1)"""
CCLE_TCGA.corr().to_csv("CCLE_TCGA.csv")

# %%
CCLE_TCGA = pd.read_csv("D:/onkar/Projects/Project_RNA_Seq_Dr.Quan/csv_ops/CCLE_TCGA.csv")

# %%
CCLE_TCGA = CCLE_TCGA.set_index("Unnamed: 0")
CCLE_TCGA = CCLE_TCGA[["G28561.NCI-H1693.1","G27452.SK-LU-1.2","G30621.TGBC11TKB.1","G26185.HCC70.2"]]
CCLE_TCGA.to_csv("CCLE_TCGA_corr.csv")

# %% [markdown]
# # PCA

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(CCLE_cell_lines_label)
principal = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
plt.figure(figsize=(8,6))
plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2], c=CCLE_cell_lines_label["Labels"], cmap="Spectral",s = 35.0)

label_1 = "TE671 Cells"
label_2 = "Soft-Tissue-Cancer"

for i in range(1):
    plt.annotate(label_1, (list(principal.iloc[0:1, 0])[i] - 25.0, list(principal.iloc[0:1, 1])[i] + 1.0))
for i in range(1):
    plt.annotate(label_2, (list(principal.iloc[595:596, 0])[i] -5.0, list(principal.iloc[595:596, 1])[i] + 1.0))

plt.colorbar()

# %%
print(round(pca.explained_variance_ratio_[0]*100, 2))
print(round(pca.explained_variance_ratio_[1]*100, 2))

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(PanRef_cell_line_label)
principal = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2], c=PanRef_cell_line_label["Labels"], cmap="Spectral")
plt.colorbar()

# %%
print(round(pca.explained_variance_ratio_[0]*100, 2))
print(round(pca.explained_variance_ratio_[1]*100, 2))

# %%
pca = PCA(n_components=2)
pca.fit(PanRef_cell_line_label)
x_new = pca.transform(PanRef_cell_line_label)  
principal = pd.DataFrame(data = x_new, columns = ['principal component 1', 'principal component 2'])
plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2], c=PanRef_cell_line_label["Labels"], cmap="Spectral")
plt.colorbar()

# %%
def myplot(score,coeff,labels=None):
    xs = score[:,0]
    ys = score[:,1]
    n = coeff.shape[0]

    plt.scatter(xs ,ys, c = PanRef_cell_line_label["Labels"], cmap="Spectral") #without scaling
    for i in range(n):
        plt.arrow(0,0, coeff[i,0], coeff[i,1],color = 'r',alpha = 0.5)
        if labels is None:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, "Var"+str(i+1), color = 'g', ha = 'center', va = 'center')
        else:
            plt.text(coeff[i,0]* 1.15, coeff[i,1] * 1.15, labels[i], color = 'g', ha = 'center', va = 'center')

plt.xlabel("PC{}".format(1))
plt.ylabel("PC{}".format(2))
plt.grid()

#Call the function. 
myplot(x_new[:,0:2], pca.components_.T) 
plt.show()

# %% [markdown]
# # Violin Plots

# %%
#PanRef_cell_line_label.to_csv("PanRef_cell_line_label.csv")
PanRef_cell_line_label = pd.read_csv("PanRef_cell_line_label.csv")

# %%
kmeans_labels = pd.Series(kmeans_labels)
PanRef_cell_line_label = PanRef_cell_line.T
PanRef_cell_line_label.reset_index(level=0, inplace=True)
PanRef_cell_line_label["Labels"] = kmeans_labels
PanRef_cell_line_label = PanRef_cell_line_label.set_index("index")
PanRef_cell_line_label.head()

# %%
PanRef_cell_line_label_subset_21 = PanRef_cell_line_label.loc[PanRef_cell_line_label['Labels'].isin([21,34])]
PanRef_cell_line_label_subset_0 = PanRef_cell_line_label.loc[PanRef_cell_line_label['Labels'].isin([0,34])]
PanRef_cell_line_label_subset_16 = PanRef_cell_line_label.loc[PanRef_cell_line_label['Labels'].isin([16,34,35,36])]

PanRef_cell_line_label_subset_21 = PanRef_cell_line_label_subset_21.iloc[1:,:]
PanRef_cell_line_label_subset_0 = PanRef_cell_line_label_subset_0.iloc[1:,:]
PanRef_cell_line_label_subset_16 = PanRef_cell_line_label_subset_16.iloc[1:,:]

corr_matrix_PanRef_subset_21 = PanRef_cell_line_label_subset_21.T.corr()
corr_matrix_PanRef_subset_0 = PanRef_cell_line_label_subset_0.T.corr()
corr_matrix_PanRef_subset_16 = PanRef_cell_line_label_subset_16.T.corr()

# %%
PanRef_cell_line_label_subset_16.head()

# %%
corr_matrix_PanRef_subset_16

# %%
ax = sns.violinplot(x=corr_matrix_PanRef_subset_21["c2_1"])

# %%
ax = sns.violinplot(x=corr_matrix_PanRef_subset_0["c2_1"])

# %%
ax = sns.violinplot(x=corr_matrix_PanRef_subset_16["c3_1"])

# %%
#CCLE_cell_lines_label.to_csv("CCLE_cell_lines_label.csv")
CCLE_cell_lines_label = pd.read_csv("CCLE_cell_lines_label.csv")

# %%
CCLE_cell_lines_label = CCLE_cell_lines.T
CCLE_cell_lines_label.reset_index(level=0, inplace=True)
CCLE_cell_lines_label["Labels"] = kmeans_labels_c
CCLE_cell_lines_label = CCLE_cell_lines_label.set_index("index")
CCLE_cell_lines_label.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-a1ac0f6bf1a7> in <module>
#       1 CCLE_cell_lines_label = CCLE_cell_lines.T
#       2 CCLE_cell_lines_label.reset_index(level=0, inplace=True)
# ----> 3 CCLE_cell_lines_label["Labels"] = kmeans_labels_c
#       4 CCLE_cell_lines_label = CCLE_cell_lines_label.set_index("index")
#       5 CCLE_cell_lines_label.head()
#
# NameError: name 'kmeans_labels_c' is not defined

# %%
CCLE_cell_lines_label_subset_21 = CCLE_cell_lines_label.loc[CCLE_cell_lines_label['Labels'].isin([21,37,38,39])]
CCLE_cell_lines_label_subset_0 = CCLE_cell_lines_label.loc[CCLE_cell_lines_label['Labels'].isin([0,37,38,39])]
corr_matrix_CCLE_subset_21 = CCLE_cell_lines_label_subset_21.T.corr()
corr_matrix_CCLE_subset_0 = CCLE_cell_lines_label_subset_0.T.corr()

# %%
CCLE_cell_lines_label_subset_21.head()

# %%
ax = sns.violinplot(x=corr_matrix_CCLE_subset_21["c2_1"])

# %%
corr_matrix_CCLE_subset_0

# %%
ax = sns.violinplot(x=corr_matrix_CCLE_subset_0["c2_1"])

# %% [markdown]
# # Cosine Similarity

# %%
CCLE_cell_lines_label_subset_21.columns

# %%
from sklearn.metrics.pairwise import cosine_similarity
cs_1 = cosine_similarity(CCLE_cell_lines_label_subset_21.iloc[:,:-1])
cs_1 = pd.DataFrame(data = cs_1, columns=CCLE_cell_lines_label_subset_21.index)
cs_1 = cs_1.set_index(CCLE_cell_lines_label_subset_21.index)
cs_1

# %%
from sklearn.metrics.pairwise import cosine_similarity
cs_2 = cosine_similarity(PanRef_cell_line_label_subset_21.iloc[:,:-1])
cs_2 = pd.DataFrame(data = cs_2, columns = PanRef_cell_line_label_subset_21.index)
cs_2 = cs_2.set_index(PanRef_cell_line_label_subset_21.index)
cs_2

# %% [markdown]
# # Spearman Correlation

# %%
corr_matrix_CCLE_subset_21 = CCLE_cell_lines_label_subset_21.T.corr(method="spearman")
corr_matrix_CCLE_subset_0 = CCLE_cell_lines_label_subset_0.T.corr(method="spearman")
corr_matrix_CCLE_subset_21

# %%
corr_matrix_PanRef_subset_21 = PanRef_cell_line_label_subset_21.T.corr(method="spearman")
corr_matrix_PanRef_subset_0 = PanRef_cell_line_label_subset_0.T.corr(method="spearman")
corr_matrix_PanRef_subset_16 = PanRef_cell_line_label_subset_16.T.corr(method="spearman")
corr_matrix_PanRef_subset_21

# %% [markdown]
# # GSEA

# %%
gene_list = PanRef_cell_line.index.str.strip().tolist()
human = gp.get_library_name(database='Human')
human[:10]

# %%
enr = gp.enrichr(gene_list=gene_list,
                 gene_sets=['KEGG_2016','KEGG_2013'],
                 organism='Human', # don't forget to set organism to the one you desired! e.g. Yeast
                 description='test_name',
                 outdir='enrichr_kegg',
                 # no_plot=True,
                 cutoff=0.9 # test dataset, use lower value from range(0,1)
                )

# %%
from gseapy.plot import barplot, dotplot

# to save your figure, make sure that ``ofname`` is not None
barplot(enr.res2d,title='KEGG_2013',)

# %% [markdown]
# # 4 - Cell Line Replicates --> Correlation Heatmaps/ PCA/ UMAP

# %%
print(sns.heatmap(cell_line_normalised.corr(), cmap = "coolwarm"))
print(cell_line_normalised.corr())

# %%
print(sns.heatmap(cell_line_normalised.corr(method="spearman"), cmap = "coolwarm"))
print(cell_line_normalised.corr(method="spearman"))

# %%
print("1-2 : ",1 - cosine(cell_line_normalised["c1_1"], cell_line_normalised["c2_1"]))
print("1-3 : ",1 - cosine(cell_line_normalised["c1_1"], cell_line_normalised["c3_1"]))
print("1-4 : ",1 - cosine(cell_line_normalised["c1_1"], cell_line_normalised["c4_1"]))
print("2-3 : ",1 - cosine(cell_line_normalised["c2_1"], cell_line_normalised["c3_1"]))
print("2-4 : ",1 - cosine(cell_line_normalised["c2_1"], cell_line_normalised["c4_1"]))
print("3-4 : ",1 - cosine(cell_line_normalised["c3_1"], cell_line_normalised["c4_1"]))

# %%
kmeans_labels = cluster.KMeans(n_clusters=4).fit_predict(cell_line_T.iloc[:,:])
standard_embedding = umap.UMAP(random_state=42).fit_transform(cell_line_T.iloc[:,:])
print(kmeans_labels)
plt.scatter(standard_embedding[:, 0], standard_embedding[:, 1], c=kmeans_labels, s=25, cmap='Spectral')
cbar = plt.colorbar(boundaries=np.arange(5)-0.5)
cbar.set_ticks(np.arange(4))
cbar.set_ticklabels(kmeans_labels)

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(cell_line_T)
principal = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])
plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2])

# %%
print(round(pca.explained_variance_ratio_[0]*100, 2))
print(round(pca.explained_variance_ratio_[1]*100, 2))

# %% [markdown]
# # CCLE UMAP and PCA

# %%
sns.heatmap(CCLE_normalised.corr(method = "spearman"), cmap = "coolwarm")

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(CCLE_normalised.T)
principal = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

a = plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2])
plt.show(a)

# %%
print(round(pca.explained_variance_ratio_[0]*100, 2))
print(round(pca.explained_variance_ratio_[1]*100, 2))

# %% [markdown]
# # PanRef (TCGA) UMAP and PCA

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(PanRef_T_scaled)
principal = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

a = plt.scatter(principal.iloc[:,0:1],principal.iloc[:,1:2])
plt.show(a)

# %%
print(round(pca.explained_variance_ratio_[0]*100, 2))
print(round(pca.explained_variance_ratio_[1]*100, 2))
